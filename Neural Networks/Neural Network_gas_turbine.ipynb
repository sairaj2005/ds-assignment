# %%
#Import Libraries
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B841-0E2D
#
#  Directory of C:\Users\SANVI\Documents\ExelR Assignment\Neural Networks
#
# 02-05-2022  01.22 PM    <DIR>          .
# 02-05-2022  01.22 PM    <DIR>          ..
# 02-05-2022  01.18 PM    <DIR>          .ipynb_checkpoints
# 20-04-2022  09.49 PM            46,843 forestfires.csv
# 20-04-2022  09.49 PM         1,155,536 gas_turbines.csv
# 02-05-2022  01.22 PM             1,043 Neural Network_gas_turbine.ipynb
# 20-04-2022  09.49 PM             1,130 problem statment(Gas turbines).txt
# 20-04-2022  09.49 PM                61 Problem_statement(fireforests).txt
#                5 File(s)      1,204,613 bytes
#                3 Dir(s)  101,649,616,896 bytes free

# %%
#Import dataset
gt = pd.read_csv("gas_turbines.csv")
gt
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
gt.shape
# Out:
# (15039, 11)

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
gt.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
gt.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
#
#            TEY       CDP        CO       NOX
# AT   -0.207495 -0.100705 -0.088588 -0.600006
# AP    0.146939  0.131198  0.041614  0.256744
# AH   -0.110272 -0.182010  0.165505  0.143061
# AFDP  0.717995  0.727152 -0.334207 -0.037299
# GTEP  0.977042  0.993784 -0.508259 -0.208496
# TIT   0.891587  0.887238 -0.688272 -0.231636
# TAT  -0.720356 -0.744740  0.063404  0.009888
# TEY   1.000000  0.988473 -0.541751 -0.102631
# CDP   0.988473  1.000000 -0.520783 -0.169103
# CO   -0.541751 -0.520783  1.000000  0.316743
# NOX  -0.102631 -0.169103  0.316743  1.000000

# %%
f, axes = plt.subplots(5,2, figsize=(15,20))

sns.regplot(x = 'TEY', y = 'AT', data = gt, ax = axes[0,0], color = 'g', scatter_kws={'alpha':0.6})
axes[0,0].set_xlabel('TEY', fontsize = 14)
axes[0,0].set_ylabel('AT', fontsize=14)
axes[0,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AP', data = gt, ax = axes[0,1], color = 'y',scatter_kws={'alpha':0.6})
axes[0,1].set_xlabel('TEY', fontsize = 14)
axes[0,1].set_ylabel('AP', fontsize=14)
axes[0,1].yaxis.set_label_position("right")
axes[0,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'AH', data = gt, ax = axes[1,0], color = 'g',scatter_kws={'alpha':0.6})
axes[1,0].set_xlabel('TEY', fontsize = 14)
axes[1,0].set_ylabel('AH', fontsize=14)
axes[1,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AFDP', data = gt, ax = axes[1,1], color = 'y',scatter_kws={'alpha':0.6})
axes[1,1].set_xlabel('TEY', fontsize = 14)
axes[1,1].set_ylabel('AFDP', fontsize=14)
axes[1,1].yaxis.set_label_position("right")
axes[1,1].yaxis.tick_right()

sns.regplot(x = 'TEY', y = 'GTEP', data = gt, ax = axes[2,0], color = 'g',scatter_kws={'alpha':0.6})
axes[2,0].set_xlabel('TEY', fontsize = 14)
axes[2,0].set_ylabel('GTEP', fontsize=14)
axes[2,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'TIT', data = gt, ax = axes[2,1], color = 'y',scatter_kws={'alpha':0.6})
axes[2,1].set_xlabel('TEY', fontsize = 14)
axes[2,1].set_ylabel('TIT', fontsize=14)
axes[2,1].yaxis.set_label_position("right")
axes[2,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'TAT', data = gt, ax = axes[3,0], color = 'g',scatter_kws={'alpha':0.6})
axes[3,0].set_xlabel('TEY', fontsize = 14)
axes[3,0].set_ylabel('TAT', fontsize=14)
axes[3,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'CDP', data = gt, ax = axes[3,1], color = 'y',scatter_kws={'alpha':0.6})
axes[3,1].set_xlabel('TEY', fontsize = 14)
axes[3,1].set_ylabel('CDP', fontsize=14)
axes[3,1].yaxis.set_label_position("right")
axes[3,1].yaxis.tick_right()

sns.regplot(x = 'TEY', y = 'CO', data = gt, ax = axes[4,0], color = 'g',scatter_kws={'alpha':0.6})
axes[4,0].set_xlabel('TEY', fontsize = 14)
axes[4,0].set_ylabel('CO', fontsize=14)
axes[4,0].yaxis.set_label_position("right")
axes[4,0].yaxis.tick_left()

sns.regplot(x = 'TEY', y = 'NOX', data = gt, ax = axes[4,1], color = 'y',scatter_kws={'alpha':0.6})
axes[4,1].set_xlabel('TEY', fontsize = 14)
axes[4,1].set_ylabel('NOX', fontsize=14)
axes[4,1].yaxis.set_label_position("right")
axes[4,1].yaxis.tick_right()

plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(gt.corr(),annot=True,cmap="inferno")
# Out:
# <AxesSubplot:>

# %%
X=gt.drop('TEY',axis=1)
X
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     CDP      CO  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  10.605  3.1547
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  10.598  3.2363
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  10.601  3.2012
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  10.606  3.1923
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  10.612  3.2484
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  10.400  4.5186
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  10.433  4.8470
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  10.483  7.9632
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  10.533  6.2494
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  10.583  4.9816
#
#           NOX
# 0      82.722
# 1      82.776
# 2      82.468
# 3      82.670
# 4      82.311
# ...       ...
# 15034  79.559
# 15035  79.917
# 15036  90.912
# 15037  93.227
# 15038  92.498
#
# [15039 rows x 10 columns]

# %%
Y=gt['TEY']
Y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(X)
x_scaled
# Out:
# array([[-1.4397781 , -0.82664395,  1.28143632, ..., -1.35733078,
#          0.53201195,  1.3878449 ],
#        [-1.44960109, -0.74864748,  1.30456402, ..., -1.36367619,
#          0.56873344,  1.39300237],
#        [-1.43472138, -0.68625031,  1.21908576, ..., -1.36095673,
#          0.5529378 ,  1.36358566],
#        ...,
#        [-1.38626659, -1.07623263,  1.47697056, ..., -1.46792219,
#          2.69592467,  2.17006209],
#        [-1.42042259, -0.99823616,  1.44159024, ..., -1.42259784,
#          1.9246834 ,  2.391165  ],
#        [-1.43073409, -0.93583899,  1.33465179, ..., -1.37727349,
#          1.35415028,  2.32153907]])

# %%
scaled_gasturbines_data=pd.DataFrame(x_scaled,columns=X.columns)
scaled_gasturbines_data
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             CDP        CO       NOX
# 0     -1.357331  0.532012  1.387845
# 1     -1.363676  0.568733  1.393002
# 2     -1.360957  0.552938  1.363586
# 3     -1.356424  0.548933  1.382878
# 4     -1.350985  0.574179  1.348591
# ...         ...       ...       ...
# 15034 -1.543161  1.145792  1.085751
# 15035 -1.513247  1.293578  1.119943
# 15036 -1.467922  2.695925  2.170062
# 15037 -1.422598  1.924683  2.391165
# 15038 -1.377273  1.354150  2.321539
#
# [15039 rows x 10 columns]

# %%
X_transformed=scaled_gasturbines_data
X_transformed
# Out:
#              AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# 0     -1.439778 -0.826644  1.281436 -0.921232 -1.379101 -1.488376  0.585240
# 1     -1.449601 -0.748647  1.304564 -0.921495 -1.363528 -1.482325  0.585240
# 2     -1.434721 -0.686250  1.219086 -0.944385 -1.351309 -1.476275  0.568715
# 3     -1.413702 -0.623853  1.169060 -0.946884 -1.348194 -1.464173  0.583969
# 4     -1.368693 -0.545857  1.161883 -0.924389 -1.354663 -1.458123  0.582698
# ...         ...       ...       ...       ...       ...       ...       ...
# 15034 -1.153182 -1.185428  1.401860 -0.865850 -1.498657 -2.063184  0.103453
# 15035 -1.303986 -1.138630  1.447753 -0.913470 -1.438759 -2.268905 -0.276638
# 15036 -1.386267 -1.076233  1.476971 -0.951488 -1.410967 -2.789257 -1.026650
# 15037 -1.420423 -0.998236  1.441590 -0.988848 -1.447624 -2.456474 -0.528337
# 15038 -1.430734 -0.935839  1.334652 -1.016605 -1.464635 -2.051083  0.057689
#
#             CDP        CO       NOX
# 0     -1.357331  0.532012  1.387845
# 1     -1.363676  0.568733  1.393002
# 2     -1.360957  0.552938  1.363586
# 3     -1.356424  0.548933  1.382878
# 4     -1.350985  0.574179  1.348591
# ...         ...       ...       ...
# 15034 -1.543161  1.145792  1.085751
# 15035 -1.513247  1.293578  1.119943
# 15036 -1.467922  2.695925  2.170062
# 15037 -1.422598  1.924683  2.391165
# 15038 -1.377273  1.354150  2.321539
#
# [15039 rows x 10 columns]

# %%
Y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
#Model building

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_transformed,Y,test_size=0.20,random_state=123)

# %%
#Mean squared Error(mse)

# %%
model=Sequential()
model.add(Dense(units=10,input_dim=10,activation ='relu',kernel_initializer='normal'))
model.add(Dense(units=6,activation='tanh',kernel_initializer='normal'))
model.add(Dense(units=1,activation='relu',kernel_initializer='normal'))

# %%
model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mse'])

# %%
model.fit(X_train,Y_train, epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 602/602 [==============================] - 3s 2ms/step - loss: 131.2130 - mse: 17470.4629
# Epoch 2/100
# 602/602 [==============================] - 1s 2ms/step - loss: 126.2625 - mse: 16195.3828
# Epoch 3/100
# 602/602 [==============================] - 1s 2ms/step - loss: 121.9001 - mse: 15112.6230
# Epoch 4/100
# 602/602 [==============================] - 1s 2ms/step - loss: 117.6229 - mse: 14087.9258
# Epoch 5/100
# 602/602 [==============================] - 1s 2ms/step - loss: 113.3778 - mse: 13107.5352
# Epoch 6/100
# 602/602 [==============================] - 1s 2ms/step - loss: 109.1477 - mse: 12165.9941
# Epoch 7/100
# 602/602 [==============================] - 1s 2ms/step - loss: 104.9250 - mse: 11263.5635
# Epoch 8/100
# 602/602 [==============================] - 1s 2ms/step - loss: 100.7064 - mse: 10394.8096
# Epoch 9/100
# 602/602 [==============================] - 1s 2ms/step - loss: 96.4900 - mse: 9562.9189
# Epoch 10/100
# 602/602 [==============================] - 1s 2ms/step - loss: 92.2745 - mse: 8767.6035
# Epoch 11/100
# 602/602 [==============================] - 1s 2ms/step - loss: 88.0594 - mse: 8008.2075
# Epoch 12/100
# 602/602 [==============================] - 1s 2ms/step - loss: 83.8456 - mse: 7283.9097
# Epoch 13/100
# 602/602 [==============================] - 1s 2ms/step - loss: 79.6319 - mse: 6594.6929
# Epoch 14/100
# 602/602 [==============================] - 1s 2ms/step - loss: 75.4169 - mse: 5940.6548
# Epoch 15/100
# 602/602 [==============================] - 1s 2ms/step - loss: 71.2012 - mse: 5322.5552
# Epoch 16/100
# 602/602 [==============================] - 1s 2ms/step - loss: 66.9855 - mse: 4739.9873
# Epoch 17/100
# 602/602 [==============================] - 1s 2ms/step - loss: 62.7698 - mse: 4192.7192
# Epoch 18/100
# 602/602 [==============================] - 1s 2ms/step - loss: 58.5541 - mse: 3681.0491
# Epoch 19/100
# 602/602 [==============================] - 1s 2ms/step - loss: 54.3384 - mse: 3205.5808
# Epoch 20/100
# 602/602 [==============================] - 1s 2ms/step - loss: 50.1227 - mse: 2765.4409
# Epoch 21/100
# 602/602 [==============================] - 1s 2ms/step - loss: 45.9070 - mse: 2360.4893
# Epoch 22/100
# 602/602 [==============================] - 1s 2ms/step - loss: 41.6913 - mse: 1991.1321
# Epoch 23/100
# 602/602 [==============================] - 1s 2ms/step - loss: 37.4756 - mse: 1657.4274
# Epoch 24/100
# 602/602 [==============================] - 1s 2ms/step - loss: 33.2615 - mse: 1359.9209
# Epoch 25/100
# 602/602 [==============================] - 1s 2ms/step - loss: 29.1165 - mse: 1098.4213
# Epoch 26/100
# 602/602 [==============================] - 1s 2ms/step - loss: 25.1877 - mse: 877.1729
# Epoch 27/100
# 602/602 [==============================] - 1s 2ms/step - loss: 22.3370 - mse: 712.6737
# Epoch 28/100
# 602/602 [==============================] - 1s 2ms/step - loss: 20.3998 - mse: 588.7871
# Epoch 29/100
# 602/602 [==============================] - 1s 2ms/step - loss: 18.4617 - mse: 478.9690
# Epoch 30/100
# 602/602 [==============================] - 1s 2ms/step - loss: 16.5392 - mse: 387.8400
# Epoch 31/100
# 602/602 [==============================] - 1s 2ms/step - loss: 14.7029 - mse: 319.0476
# Epoch 32/100
# 602/602 [==============================] - 1s 2ms/step - loss: 12.9642 - mse: 274.1511
# Epoch 33/100
# 602/602 [==============================] - 1s 2ms/step - loss: 7.3803 - mse: 154.0456
# Epoch 34/100
# 602/602 [==============================] - 1s 2ms/step - loss: 6.1044 - mse: 124.4844
# Epoch 35/100
# 602/602 [==============================] - 1s 2ms/step - loss: 5.4180 - mse: 102.8918
# Epoch 36/100
# 602/602 [==============================] - 1s 2ms/step - loss: 4.7960 - mse: 82.4536
# Epoch 37/100
# 602/602 [==============================] - 1s 2ms/step - loss: 4.1265 - mse: 63.4054
# Epoch 38/100
# 602/602 [==============================] - 1s 2ms/step - loss: 3.4931 - mse: 46.9049
# Epoch 39/100
# 602/602 [==============================] - 1s 2ms/step - loss: 2.9094 - mse: 33.3492
# Epoch 40/100
# 602/602 [==============================] - 1s 2ms/step - loss: 2.4368 - mse: 23.6026
# Epoch 41/100
# 602/602 [==============================] - 1s 2ms/step - loss: 2.0747 - mse: 17.0449
# Epoch 42/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.7936 - mse: 12.4993
# Epoch 43/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.5656 - mse: 9.2653
# Epoch 44/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.3790 - mse: 6.9953
# Epoch 45/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.2243 - mse: 5.3416
# Epoch 46/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.1025 - mse: 4.1561
# Epoch 47/100
# 602/602 [==============================] - 1s 2ms/step - loss: 1.0054 - mse: 3.3288
# Epoch 48/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.9294 - mse: 2.7298
# Epoch 49/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.8665 - mse: 2.3004
# Epoch 50/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.8129 - mse: 1.9843
# Epoch 51/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.7833 - mse: 1.7554
# Epoch 52/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.7480 - mse: 1.5675
# Epoch 53/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.7228 - mse: 1.4183
# Epoch 54/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6990 - mse: 1.3050
# Epoch 55/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6841 - mse: 1.2208
# Epoch 56/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6617 - mse: 1.1214
# Epoch 57/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6467 - mse: 1.0592
# Epoch 58/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6385 - mse: 1.0026
# Epoch 59/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6257 - mse: 0.9508
# Epoch 60/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6138 - mse: 0.8981
# Epoch 61/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.6052 - mse: 0.8692
# Epoch 62/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5922 - mse: 0.8221
# Epoch 63/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5838 - mse: 0.7884
# Epoch 64/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5746 - mse: 0.7628
# Epoch 65/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5765 - mse: 0.7468
# Epoch 66/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5530 - mse: 0.6958
# Epoch 67/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5535 - mse: 0.6878
# Epoch 68/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5432 - mse: 0.6585
# Epoch 69/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5439 - mse: 0.6507
# Epoch 70/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5375 - mse: 0.6316
# Epoch 71/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5281 - mse: 0.6146
# Epoch 72/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5231 - mse: 0.6015
# Epoch 73/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5271 - mse: 0.6020
# Epoch 74/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5183 - mse: 0.5867
# Epoch 75/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5149 - mse: 0.5773
# Epoch 76/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5106 - mse: 0.5645
# Epoch 77/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5064 - mse: 0.5547
# Epoch 78/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5042 - mse: 0.5497
# Epoch 79/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.5049 - mse: 0.5471
# Epoch 80/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4956 - mse: 0.5315
# Epoch 81/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4935 - mse: 0.5280
# Epoch 82/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4967 - mse: 0.5280
# Epoch 83/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4910 - mse: 0.5132
# Epoch 84/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4924 - mse: 0.5109
# Epoch 85/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4915 - mse: 0.5097
# Epoch 86/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4902 - mse: 0.5083
# Epoch 87/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4895 - mse: 0.5025
# Epoch 88/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4809 - mse: 0.4869
# Epoch 89/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4801 - mse: 0.4913
# Epoch 90/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4799 - mse: 0.4908
# Epoch 91/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4781 - mse: 0.4812
# Epoch 92/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4763 - mse: 0.4759
# Epoch 93/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4809 - mse: 0.4854
# Epoch 94/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4723 - mse: 0.4660
# Epoch 95/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4782 - mse: 0.4756
# Epoch 96/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4746 - mse: 0.4670
# Epoch 97/100
# 602/602 [==============================] - 1s 1ms/step - loss: 0.4710 - mse: 0.4670
# Epoch 98/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4651 - mse: 0.4556
# Epoch 99/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4677 - mse: 0.4596
# Epoch 100/100
# 602/602 [==============================] - 1s 2ms/step - loss: 0.4676 - mse: 0.4607

# %%
#Model evaluation

# %%
scores = model.evaluate(X_test,Y_test)
print((model.metrics_names[1]))
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4686 - mse: 0.4747
# mse
