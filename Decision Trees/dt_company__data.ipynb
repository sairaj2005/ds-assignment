# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B841-0E2D
#
#  Directory of C:\Users\SANVI\Documents\ExelR Assignment\Decision Trees
#
# 03-05-2022  01.06 PM    <DIR>          .
# 03-05-2022  01.06 PM    <DIR>          ..
# 02-05-2022  10.00 PM    <DIR>          .ipynb_checkpoints
# 20-04-2022  09.46 PM            17,023 Company_Data.csv
# 03-05-2022  01.06 PM            28,467 dt_company__data.ipynb
# 29-04-2022  05.30 PM         1,676,614 DT_company_data.ipynb
# 02-05-2022  09.54 PM            53,491 dt_fraudcheck.ipynb
# 20-04-2022  09.46 PM            21,837 Fraud_check.csv
# 20-04-2022  09.46 PM             1,377 problem statement(company data).txt
# 20-04-2022  09.46 PM               460 Problem_statement(Fraudcheck).txt
#                7 File(s)      1,799,269 bytes
#                3 Dir(s)  101,651,210,240 bytes free

# %%
data = pd.read_csv("Company_Data.csv")
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
data.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
data['ShelveLoc'] = data['ShelveLoc'].map({'Good':1,'Medium':2,'Bad':3})

# %%
data = pd.get_dummies(data,columns=['Urban','US'], drop_first=True)

# %%
data['Sales'] = pd.cut(np.array(data.Sales.values), 3, labels=["Low","Medium","High"])

# %%
data
# Out:
#       Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  \
# 0    Medium        138      73           11         276    120          3
# 1      High        111      48           16         260     83          1
# 2    Medium        113      35           10         269     80          2
# 3    Medium        117     100            4         466     97          2
# 4       Low        141      64            3         340    128          3
# ..      ...        ...     ...          ...         ...    ...        ...
# 395    High        138     108           17         203    128          1
# 396  Medium        139      23            3          37    120          2
# 397  Medium        162      26           12         368    159          2
# 398  Medium        100      79            7         284     95          3
# 399  Medium        134      37            0          27    120          1
#
#      Age  Education  Urban_Yes  US_Yes
# 0     42         17          1       1
# 1     65         10          1       1
# 2     59         12          1       1
# 3     55         14          1       1
# 4     38         13          1       0
# ..   ...        ...        ...     ...
# 395   33         14          1       1
# 396   55         11          0       1
# 397   40         18          1       1
# 398   50         12          1       1
# 399   49         16          1       1
#
# [400 rows x 11 columns]

# %%
X=data.iloc[:,1:]
y=data['Sales']

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120          3   42
# 1          111      48           16         260     83          1   65
# 2          113      35           10         269     80          2   59
# 3          117     100            4         466     97          2   55
# 4          141      64            3         340    128          3   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128          1   33
# 396        139      23            3          37    120          2   55
# 397        162      26           12         368    159          2   40
# 398        100      79            7         284     95          3   50
# 399        134      37            0          27    120          1   49
#
#      Education  Urban_Yes  US_Yes
# 0           17          1       1
# 1           10          1       1
# 2           12          1       1
# 3           14          1       1
# 4           13          1       0
# ..         ...        ...     ...
# 395         14          1       1
# 396         11          0       1
# 397         18          1       1
# 398         12          1       1
# 399         16          1       1
#
# [400 rows x 10 columns]

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size =0.33, random_state= 40)

# %%
model = DecisionTreeClassifier(criterion = 'entropy', max_depth=3)
model.fit(X_train, y_train)
tree.plot_tree(model)
# Out:
# [Text(167.4, 190.26, 'X[5] <= 1.5\nentropy = 1.302\nsamples = 268\nvalue = [37, 62, 169]'),
#  Text(83.7, 135.9, 'X[4] <= 97.5\nentropy = 0.998\nsamples = 59\nvalue = [28, 0, 31]'),
#  Text(41.85, 81.53999999999999, 'X[8] <= 0.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 0, 1]'),
#  Text(20.925, 27.180000000000007, 'entropy = 1.0\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[6] <= 68.5\nentropy = 0.944\nsamples = 47\nvalue = [17, 0, 30]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.992\nsamples = 38\nvalue = [17, 0, 21]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9]'),
#  Text(251.10000000000002, 135.9, 'X[4] <= 106.5\nentropy = 1.111\nsamples = 209\nvalue = [9, 62, 138]'),
#  Text(209.25, 81.53999999999999, 'X[0] <= 124.5\nentropy = 1.029\nsamples = 67\nvalue = [9, 7, 51]'),
#  Text(188.32500000000002, 27.180000000000007, 'entropy = 0.818\nsamples = 50\nvalue = [2, 7, 41]'),
#  Text(230.175, 27.180000000000007, 'entropy = 0.977\nsamples = 17\nvalue = [7, 0, 10]'),
#  Text(292.95, 81.53999999999999, 'X[5] <= 2.5\nentropy = 0.963\nsamples = 142\nvalue = [0, 55, 87]'),
#  Text(272.02500000000003, 27.180000000000007, 'entropy = 0.758\nsamples = 96\nvalue = [0, 21, 75]'),
#  Text(313.875, 27.180000000000007, 'entropy = 0.828\nsamples = 46\nvalue = [0, 34, 12]')]

# %%
y_train
# Out:
# 290    Medium
# 336       Low
# 212      High
# 296    Medium
# 10     Medium
#         ...
# 306       Low
# 165       Low
# 7        High
# 219    Medium
# 326       Low
# Name: Sales, Length: 268, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
model = DecisionTreeClassifier(criterion = 'entropy', max_depth=3)
model.fit(X_train, y_train)
tree.plot_tree(model)
# Out:
# [Text(167.4, 190.26, 'X[5] <= 1.5\nentropy = 1.302\nsamples = 268\nvalue = [37, 62, 169]'),
#  Text(83.7, 135.9, 'X[4] <= 97.5\nentropy = 0.998\nsamples = 59\nvalue = [28, 0, 31]'),
#  Text(41.85, 81.53999999999999, 'X[8] <= 0.5\nentropy = 0.414\nsamples = 12\nvalue = [11, 0, 1]'),
#  Text(20.925, 27.180000000000007, 'entropy = 1.0\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0, 0]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[6] <= 68.5\nentropy = 0.944\nsamples = 47\nvalue = [17, 0, 30]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.992\nsamples = 38\nvalue = [17, 0, 21]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 9]'),
#  Text(251.10000000000002, 135.9, 'X[4] <= 106.5\nentropy = 1.111\nsamples = 209\nvalue = [9, 62, 138]'),
#  Text(209.25, 81.53999999999999, 'X[0] <= 124.5\nentropy = 1.029\nsamples = 67\nvalue = [9, 7, 51]'),
#  Text(188.32500000000002, 27.180000000000007, 'entropy = 0.818\nsamples = 50\nvalue = [2, 7, 41]'),
#  Text(230.175, 27.180000000000007, 'entropy = 0.977\nsamples = 17\nvalue = [7, 0, 10]'),
#  Text(292.95, 81.53999999999999, 'X[5] <= 2.5\nentropy = 0.963\nsamples = 142\nvalue = [0, 55, 87]'),
#  Text(272.02500000000003, 27.180000000000007, 'entropy = 0.758\nsamples = 96\nvalue = [0, 21, 75]'),
#  Text(313.875, 27.180000000000007, 'entropy = 0.828\nsamples = 46\nvalue = [0, 34, 12]')]

# %%
y_train.value_counts()
# Out:
# Medium    169
# Low        62
# High       37
# Name: Sales, dtype: int64

# %%
#Predicting on test data
preds = model.predict(X_test) # predicting on test data set 
pd.Series(preds).value_counts() # getting the count of each category
# Out:
# Medium    112
# Low        14
# High        6
# dtype: int64

# %%
pd.crosstab(y_test, preds)
# Out:
# col_0   High  Low  Medium
# Sales
# Low        0   10      30
# Medium     1    4      73
# High       5    0       9

# %%
np.mean(preds==y_test)
# Out:
# 0.6666666666666666

# %% [markdown]
# ## Assigning a model

# %%
dcmodel =  BaggingClassifier(DecisionTreeClassifier(max_depth = 7), random_state=10) 
# dcmodel =  AdaBoostClassifier(DecisionTreeClassifier(max_depth = 6), random_state=0)

# %%
dcmodel = dcmodel.fit(X_train,y_train) #train decision tree

# %%
y_predict = dcmodel.predict(X_test)

# %%
print("Accuracy : ", accuracy_score(y_test,y_predict)*100 )
# Out:
# Accuracy :  68.18181818181817
